# %% [markdown]
# # Open Notebook & Additional Resources
#
# <a target="_blank" href="https://colab.research.google.com/github/Nicolepcx/ORM_AI_Agents_Bootcamp/blob/main/hands_on/DAY_1_HANDS_ON_SESSION_2_ToT.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
# <a target="_blank" href="https://learning.oreilly.com/library/view/ai-agents-the/0642572247775/">
#   <img src="https://img.shields.io/badge/AI%20Agents%20Book-Read%20on%20O'Reilly-d40101?style=flat" alt="AI Agents Book – Read on O'Reilly"/>
# </a>

# %% [markdown]
# <font color="red" size="10">
# <b>HANDS-ON TIME: 15 mins</b>
# </font>

# %% [markdown]
# # About this notebook
#
# This notebook walks through a small but complete multi agent writing workflow that plans, researches, and drafts a developer focused blog post. It combines structured outputs, a tool using research step, and a simple LangGraph pipeline with checkpoints.
#
# ## What it shows
#
# * **A four stage graph**
#
#   1. **propose** generates three creative options with structured output
#   2. **reflect** critiques and selects the best option with a stronger judge
#   3. **research** uses OpenAI web search to collect sources and synthesize JSON
#   4. **draft** produces a final outline and intro for the chosen plan
# * **Separation of roles and models**
#
#   * a small creative generator
#   * a stricter judge
#   * a tool bound researcher
#   * a small writer for the final draft
# * **Typed state** with accumulated messages, option and choice JSON, synthesized sources, and the final draft
# * **In memory checkpoints** with `MemorySaver`
# * **Readable streaming trace** that prints per node updates during execution
# * **Graph preview** via Mermaid PNG
#
# ## What you will run
#
# 1. Load `OPENAI_API_KEY` from `.env`.
# 2. Define an `internet_search` tool that returns compact JSON results using OpenAI `web_search`.
# 3. Create Pydantic schemas for options, choice, and queries to keep outputs structured.
# 4. Wire a **linear LangGraph** with four nodes and compile it with a checkpointer.
# 5. Start a run with a topic prompt and watch the system stream updates from each node.
# 6. Inspect the final draft and render the graph image.
#
# ## How it works
#
# * **Propose options** uses `with_structured_output(OptionsPayload)` to force three options with consistent fields.
# * **Reflect and select** uses a stronger model with `ChoicePayload` to pick the best option by index with a rationale. The code clamps the index defensively.
# * **Research with tools**
#
#   * the researcher proposes 1 to 2 focused queries tied to the chosen option
#   * the notebook calls `internet_search` for each query and collects raw findings
#   * a compact synthesis step turns findings into a clean `sources_json` payload with suggested citations
# * **Draft outline and intro** converts the chosen plan and sources into a title, audience sentence, a five section outline, and a short intro.
#
# ## Why this pattern
#
# * Clear role separation improves quality and transparency. Generation, evaluation, research, and writing are handled by different prompts and sometimes different models.
# * Structured outputs reduce ambiguity and make routing trivial.
# * Tool use is explicit and observable which makes the process auditable.
# * LangGraph keeps control flow readable and provides thread scoped memory with almost no boilerplate.
#
# ## Extend and adapt
#
# * Add domain filters or user location to the OpenAI web search tool.
# * Add a factuality checker or citation verifier between research and drafting.
# * Persist checkpoints to a database for long running projects.
# * Add a final formatter node that turns the draft into Markdown or HTML.
#
# ## Requirements and notes
#
# * `OPENAI_API_KEY` is required.
# * Internet results change over time. Expect different sources on different runs.
# * The creative model is set slightly higher temperature. The judge is near zero for stability.
# * Token and API costs can add up when streaming multiple stages.
#
# ## Intended audience
#
# Engineers, technical writers, and researchers who want a practical template for a small, role based writing agent that mixes structured planning, tool assisted research, and drafting inside a simple LangGraph workflow.

# %% [markdown]
# # Open in Colab
# <a target="_blank" href="https://colab.research.google.com/github/Nicolepcx/ai-agents-the-definitive-guide/blob/main/CH02/ch02_ToT.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Dependencies

# %%
# !pip install -q langchain==0.3.27 \
                langgraph==0.6.7 \
                langchain-openai==0.3.32 \
                langchain_experimental==0.3.4 \
                langchain_community==0.3.29 \
                python-dotenv==1.0.1 \
                langchain-core==0.3.75 \
                openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.3/153.3 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.2/209.2 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 24.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.0/444.0 kB 22.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.6/948.6 kB 55.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 4.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.

# %% [markdown]
# # API Setup

# %%
# --- API Key Setup ---
# Option 1 (preferred): create a `.env` file in your project folder with:
# OPENAI_API_KEY=your_openai_key_here
#
# Option 2: set it directly in the notebook with magic:
# %env OPENAI_API_KEY=your_openai_key_here

from dotenv import load_dotenv
import os

# Load from .env if available
load_dotenv()

OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# Fallback: ask if still missing
if not OPENAI_API_KEY:
    print("⚠️ OPENAI_API_KEY not found. You can set it with `%env` in the notebook or enter it below.")
    OPENAI_API_KEY = input("Enter your OPENAI_API_KEY: ").strip()

print("✅ OPENAI_API_KEY loaded successfully!")
# Out:
# ✅ OPENAI_API_KEY loaded successfully!

# %% [markdown]
# # Imports

# %%
import os, json, uuid, re, time
from typing import Annotated, List, TypedDict

from pydantic import BaseModel, Field
from openai import OpenAI

from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, AIMessage, BaseMessage, ToolMessage
from langchain_core.tools import tool

from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.checkpoint.memory import MemorySaver

# %% [markdown]
# # Tool: internet_search

# %%
@tool("internet_search")
def internet_search(query: str) -> str:
    """Search web via OpenAI web_search. Returns compact JSON list."""
    key = os.getenv("OPENAI_API_KEY")
    if not key:
        return "[]"

    client = OpenAI(api_key=key)
    response = client.responses.create(
        model="gpt-4.1-mini",
        tools=[{"type": "web_search"}],
        input=(
            "Return ONLY a JSON array with up to 5 search results for this query. "
            "Each item must have: title, link, snippet, source. "
            f"Query: {query}"
        ),
    )

    text = (getattr(response, "output_text", "") or "").strip()
    if text.startswith("```"):
        m = re.search(r"```(?:json)?\s*(.*?)\s*```", text, flags=re.DOTALL)
        if m:
            text = m.group(1).strip()

    try:
        parsed = json.loads(text)
        if isinstance(parsed, list):
            out = []
            for r in parsed[:5]:
                out.append({
                    "title": (r or {}).get("title"),
                    "link": (r or {}).get("link") or (r or {}).get("url"),
                    "snippet": (r or {}).get("snippet"),
                    "source": (r or {}).get("source"),
                })
            return json.dumps(out, ensure_ascii=False)
    except Exception:
        pass

    return "[]"

tools = [internet_search]

# %% [markdown]
# # Models: small generator, stronger judge, tool-bound researcher

# %%
baseline_llm  = ChatOpenAI(model="gpt-5.4-nano-2026-03-17", temperature=0.2)   # single-shot baseline
gen_llm       = ChatOpenAI(model="gpt-5.4-nano-2026-03-17", temperature=0.7)   # creative, cheaper
judge_llm     = ChatOpenAI(model="gpt-5.4-mini-2026-03-17", temperature=0.2)        # stricter judge
research_llm  = ChatOpenAI(model="gpt-5.4-nano-2026-03-17", temperature=0.2).bind_tools(tools, tool_choice="auto")
writer_llm    = gen_llm  # reuse small model for drafting

# %% [markdown]
# # Structured payloads (Pydantic v2)

# %%
class Option(BaseModel):
    title: str
    audience: str
    angle: str
    outline: List[str] = Field(min_length=5, max_length=5)
    rationale: str

class OptionsPayload(BaseModel):
    options: List[Option] = Field(min_length=3, max_length=3)

class ChoicePayload(BaseModel):
    choice_index: int = Field(ge=0, le=2)
    rationale: str

class Queries(BaseModel):
    queries: List[str] = Field(min_length=1, max_length=2)

class BroadQueries(BaseModel):
    queries: List[str] = Field(min_length=3, max_length=5)

# %% [markdown]
# # State

# %%
class BlogState(TypedDict):
    messages: Annotated[List[BaseMessage], add_messages]
    topic: str
    options_json: str | None
    choice_json: str | None
    sources_json: str | None
    draft: str | None

# %% [markdown]
# # Nodes

# %%
def propose_options(state: BlogState) -> BlogState:
    """Generator (small): propose 3 creative approaches (ToT-style branching)."""
    proposer = gen_llm.with_structured_output(OptionsPayload)
    prompt = (
        "Generate exactly 3 distinct approaches for a developer-focused blog on:\n"
        f"{state['topic']}\n\nFor each option, provide: title, audience, angle, "
        "a 5-bullet outline, and a concise rationale."
    )
    payload: OptionsPayload = proposer.invoke(prompt)
    options_json = payload.model_dump_json()
    return {
        "options_json": options_json,
        "messages": [AIMessage(content=options_json)],
    }


def reflect_and_select(state: BlogState) -> BlogState:
    """Judge (stronger): critique options and select best one."""
    chooser = judge_llm.with_structured_output(ChoicePayload)
    eval_prompt = (
        "Evaluate the 3 approaches for clarity, originality, developer relevance, "
        "and feasibility under time constraints. Pick ONE by index 0..2 and justify.\n\n"
        f"Options JSON:\n{state['options_json']}"
    )
    choice: ChoicePayload = chooser.invoke(eval_prompt)
    opts = json.loads(state["options_json"])["options"]
    choice.choice_index = max(0, min(choice.choice_index, len(opts) - 1))
    choice_json = choice.model_dump_json()
    return {
        "choice_json": choice_json,
        "messages": [AIMessage(content=choice_json)],
    }


def research_with_tools(state: BlogState) -> BlogState:
    """Focused researcher: gather only minimal evidence for selected option."""
    selected = json.loads(state["choice_json"])
    selected_idx = selected["choice_index"]
    chosen_option = json.loads(state["options_json"])["options"][selected_idx]

    q_llm = research_llm.with_structured_output(Queries)
    q_payload: Queries = q_llm.invoke(
        "You are supporting a writer, not exploring the whole space. "
        "Create only 1 or 2 focused web queries that gather evidence for the SINGLE chosen blog direction below. "
        "Avoid broad surveys, random examples, or searches that expand beyond the selected angle.\n\n"
        f"Topic: {state['topic']}\n"
        f"Chosen title: {chosen_option['title']}\n"
        f"Chosen audience: {chosen_option['audience']}\n"
        f"Chosen angle: {chosen_option['angle']}\n"
        f"Chosen outline: {json.dumps(chosen_option['outline'], ensure_ascii=False)}"
    )

    findings = []
    for q in q_payload.queries:
        res = internet_search.invoke({"query": q})
        try:
            findings.append({"query": q, "results": json.loads(res)})
        except Exception:
            findings.append({"query": q, "results": []})

    synth = research_llm.invoke([
        (
            "system",
            "Return JSON only. Summarize only the evidence most useful for writing the chosen blog direction. "
            "Prefer 2 to 4 citations total, not a large source dump."
        ),
        HumanMessage(
            content=(
                f"Chosen option:\n{json.dumps(chosen_option, ensure_ascii=False)}\n\n"
                f"Search findings:\n{json.dumps(findings, ensure_ascii=False)}"
            )
        )
    ])
    return {
        "sources_json": synth.content,
        "messages": [AIMessage(content=synth.content)],
    }


def research_with_tools_broad(state: BlogState) -> BlogState:
    """Broad researcher: intentionally explore wider source space for comparison."""
    q_llm = research_llm.with_structured_output(BroadQueries)
    q_payload: BroadQueries = q_llm.invoke(
        "Propose 3 to 5 precise web queries (docs/repos/papers/blog posts) to support the chosen approach.\n"
        f"Topic: {state['topic']}\nOptions: {state['options_json']}\nChoice: {state['choice_json']}"
    )

    findings = []
    for q in q_payload.queries:
        res = internet_search.invoke({"query": q})
        try:
            findings.append({"query": q, "results": json.loads(res)})
        except Exception:
            findings.append({"query": q, "results": []})

    synth = research_llm.invoke([
        ("system", "Return JSON only."),
        HumanMessage(content=json.dumps(findings, ensure_ascii=False))
    ])
    return {
        "sources_json": synth.content,
        "messages": [AIMessage(content=synth.content)],
    }


def draft_outline_and_intro(state: BlogState) -> BlogState:
    """Writer (small): outline + intro from chosen plan and sources."""
    system = (
        "You are a senior technical writer. Using the chosen approach and sources, produce:\n"
        "1) Final title\n2) Audience sentence\n3) 5-section outline (2-3 bullets each)\n"
        "4) 150-200 word intro. Be clear, concrete, and avoid hype."
    )
    ai = writer_llm.invoke([
        ("system", system),
        HumanMessage(content=f"Choice:\n{state['choice_json']}\n\nSources:\n{state['sources_json']}")
    ])
    return {
        "draft": ai.content,
        "messages": [ai],
    }


def run_single_llm(topic: str) -> str:
    prompt = (
        "You are a senior technical writer. Create a developer-focused blog post plan on this topic:\n"
        f"{topic}\n\n"
        "Return:\n"
        "1) Final title\n"
        "2) Audience sentence\n"
        "3) 5-section outline (2-3 bullets each)\n"
        "4) 150-200 word intro\n\n"
        "Do everything in one shot without separate planning, judging, or external research."
    )
    return baseline_llm.invoke(prompt).content

# %% [markdown]
# # Graph wiring

# %%
def build_planner_app(research_node_fn):
    g = StateGraph(BlogState)
    g.add_node("propose", propose_options)
    g.add_node("reflect", reflect_and_select)
    g.add_node("research", research_node_fn)
    g.add_node("draft", draft_outline_and_intro)

    g.add_edge(START, "propose")
    g.add_edge("propose", "reflect")
    g.add_edge("reflect", "research")
    g.add_edge("research", "draft")
    g.add_edge("draft", END)
    return g.compile(checkpointer=MemorySaver())


app_focused = build_planner_app(research_with_tools)
app_broad = build_planner_app(research_with_tools_broad)
app = app_focused

# %% [markdown]
# # Run and compare workflows (with timing)

# %%
topic = "AI Agents for Developers: From LLMs to Tool-Using Systems"


def run_planner(app_obj, label: str):
    cfg = {"configurable": {"thread_id": f"{label}-{uuid.uuid4()}"}, "recursion_limit": 40}
    initial: BlogState = {
        "messages": [HumanMessage(content="Plan a blog post about AI agents for developers.")],
        "topic": topic,
        "options_json": None,
        "choice_json": None,
        "sources_json": None,
        "draft": None,
    }

    print(f"\n===== {label.upper()} TRACE =====")
    t0 = time.perf_counter()
    for update in app_obj.stream(initial, config=cfg, stream_mode="updates"):
        for node, payload in update.items():
            print(f"\n[enter {node}] keys: {list(payload.keys())}")
            if "messages" in payload and payload["messages"]:
                m = payload["messages"][-1]
                text = getattr(m, "content", "")
                print((text if isinstance(text, str) else str(text))[:300], "...")
    elapsed = time.perf_counter() - t0
    final_state = app_obj.get_state(cfg).values
    return final_state, elapsed


# 1) Single LLM baseline
print("===== SINGLE LLM (NO HANDOFFS) =====")
t0_single = time.perf_counter()
single_llm_output = run_single_llm(topic)
single_elapsed = time.perf_counter() - t0_single
print(single_llm_output)

# 2) Focused planner workflow
final_focused, focused_elapsed = run_planner(app_focused, "focused")

# 3) Broad planner workflow (comparison)
final_broad, broad_elapsed = run_planner(app_broad, "broad")

print("\n===== TIMING SUMMARY (SECONDS) =====")
print(f"Single LLM:      {single_elapsed:.2f}")
print(f"Planner focused: {focused_elapsed:.2f}")
print(f"Planner broad:   {broad_elapsed:.2f}")

print("\n===== FINAL DRAFTS =====")
print("\n--- Single LLM ---\n")
print(single_llm_output)
print("\n--- Planner Focused ---\n")
print(final_focused.get("draft") or "")
print("\n--- Planner Broad ---\n")
print(final_broad.get("draft") or "")
# Out:
# ===== SINGLE LLM (NO HANDOFFS) =====
# 1) **Final title**
# **AI Agents for Developers: From LLMs to Tool‑Using Systems**
#
# 2) **Audience sentence**
# Built for software engineers and platform developers who already use LLMs and want to design, evaluate, and ship reliable tool‑using agent systems.
#
# 3) **5-section outline**
# **Section 1 — Mental Model: LLM → Agent → Tool-Using System**
# - Clarify agent responsibilities: planning, acting, observing, and learning from feedback
# - Distinguish “prompted LLM apps” vs. iterative tool-using agents
# - Map core components: model, policy/planner, tool registry, state store, and execution loop
#
# **Section 2 — Agent Architectures Developers Can Build**
# - Compare common patterns: ReAct-style loops, planner/executor, graph/state machines
# - Coverage for multi-step tasks, branching, and recovery strategies
# - Design guidance for separating “reasoning text” from “action schemas”
#
# **Section 3 — Tooling: Interfaces, Schemas, and Safety Boundaries**
# - Define tool contracts (inputs/outputs), validation, idempotency, and timeouts
# - Guardrails: allowlists, permissioning, rate limits, and sandboxing
# - Handling sensitive data: redaction, secrets management, audit logs
#
# **Section 4 — Reliability Engineering: Testing, Evaluation, and Observability**
# - Test strategies: golden runs, tool-mocking, scenario-based evals, regression suites
# - Instrumentation: traces, step-level metrics, cost/latency dashboards
# - Failure modes: hallucinated tool calls, partial execution, infinite loops
#
# **Section 5 — Shipping Playbook: Performance, Cost, and Operations**
# - Caching, batching, streaming, and model routing by task type
# - Human-in-the-loop patterns for high-risk actions
# - Deployment checklist: rollouts, feature flags, incident response, and postmortems
#
# 4) **150–200 word intro**
# LLMs are getting you fluent answers. But in production, developers need systems that *do* things: fetch data, run queries, update tickets, generate code changes, and coordinate multi-step workflows—safely and reliably. That’s where AI agents come in.
#
# In this post, we’ll move from the basics of calling a language model to building tool-using systems that can plan, choose actions, execute tools, and react to results. You’ll learn practical architecture patterns you can implement today, including how to model agent state, define tool contracts, and enforce safety boundaries like allowlists and permissions.
#
# We’ll also cover the engineering side most teams underestimate: evaluation methods that catch regressions before users do, observability to debug step-by-step behavior, and reliability strategies to avoid common failure modes such as hallucinated tool calls or runaway loops. By the end, you’ll have a developer-focused blueprint for turning LLM capabilities into maintainable agent workflows.
#
# ===== FOCUSED TRACE =====
#
# [enter propose] keys: ['options_json', 'messages']
# {"options":[{"title":"LLM→Agent Evolution: Building the First Tool-Using Loop","audience":"Backend and full-stack developers who can code in Python/TypeScript and want a practical “from scratch” mental model","angle":"Start with a plain LLM call, then incrementally add planning, tool calling, state, ...
#
# [enter reflect] keys: ['choice_json', 'messages']
# {"choice_index":0,"rationale":"Option 0 is the clearest and most time-feasible choice while still being practically useful. Its progression from a simple LLM call to a working tool-using agent gives readers an intuitive mental model and a concrete implementation path, which is ideal for a limited-ti ...
#
# [enter research] keys: ['sources_json', 'messages']
#  ...
#
# [enter draft] keys: ['draft', 'messages']
# ## 1) Final title
# **From Prompt to Tool-Using Agent: A Practical Path to Building Something That Works**
#
# ## 2) Audience sentence
# This guide is for software engineers and technical writers who want to turn an LLM prompt into a reliable, tool-using agent with a concrete, step-by-step implementati ...
#
# ===== BROAD TRACE =====
#
# [enter propose] keys: ['options_json', 'messages']
# {"options":[{"title":"Agent Architecture in Practice: LLMs + Tools + Control Loops","audience":"Backend/frontend engineers, solution architects, and tech leads building agentic features","angle":"Go from “chat model” to a working tool-using agent by covering the control loop, tool interfaces, state  ...
#
# [enter reflect] keys: ['choice_json', 'messages']
# {"choice_index":1,"rationale":"Option 1 is the strongest overall balance of clarity, originality, developer relevance, and feasibility under time constraints. It has a crisp, teachable thesis: making tool-using agents more reliable through structured outputs, function calling, and policy-based decis ...
#
# [enter research] keys: ['sources_json', 'messages']
# {
#   "summary": [
#     {
#       "topic": "Reliability of OpenAI function calling / structured outputs",
#       "key_points": [
#         "OpenAI Structured Outputs (June 2024) guarantees function-call arguments match the provided JSON Schema exactly (key/type compliance).",
#         "This applies both to f ...
#
# [enter draft] keys: ['draft', 'messages']
# ## 1) Final title
# **Making Tool-Using LLM Agents Reliable: Structured Outputs, Typed Function Calls, and Policy Guardrails**
#
# ## 2) Audience sentence
# This guide is for developers building LLM “agents” that call tools (APIs, databases, workflows) and need predictable, testable behavior under real fai ...
#
# ===== TIMING SUMMARY (SECONDS) =====
# Single LLM:      5.60
# Planner focused: 22.05
# Planner broad:   52.94
#
# ===== FINAL DRAFTS =====
#
# --- Single LLM ---
#
# 1) **Final title**
# **AI Agents for Developers: From LLMs to Tool‑Using Systems**
#
# 2) **Audience sentence**
# Built for software engineers and platform developers who already use LLMs and want to design, evaluate, and ship reliable tool‑using agent systems.
#
# 3) **5-section outline**
# **Section 1 — Mental Model: LLM → Agent → Tool-Using System**
# - Clarify agent responsibilities: planning, acting, observing, and learning from feedback
# - Distinguish “prompted LLM apps” vs. iterative tool-using agents
# - Map core components: model, policy/planner, tool registry, state store, and execution loop
#
# **Section 2 — Agent Architectures Developers Can Build**
# - Compare common patterns: ReAct-style loops, planner/executor, graph/state machines
# - Coverage for multi-step tasks, branching, and recovery strategies
# - Design guidance for separating “reasoning text” from “action schemas”
#
# **Section 3 — Tooling: Interfaces, Schemas, and Safety Boundaries**
# - Define tool contracts (inputs/outputs), validation, idempotency, and timeouts
# - Guardrails: allowlists, permissioning, rate limits, and sandboxing
# - Handling sensitive data: redaction, secrets management, audit logs
#
# **Section 4 — Reliability Engineering: Testing, Evaluation, and Observability**
# - Test strategies: golden runs, tool-mocking, scenario-based evals, regression suites
# - Instrumentation: traces, step-level metrics, cost/latency dashboards
# - Failure modes: hallucinated tool calls, partial execution, infinite loops
#
# **Section 5 — Shipping Playbook: Performance, Cost, and Operations**
# - Caching, batching, streaming, and model routing by task type
# - Human-in-the-loop patterns for high-risk actions
# - Deployment checklist: rollouts, feature flags, incident response, and postmortems
#
# 4) **150–200 word intro**
# LLMs are getting you fluent answers. But in production, developers need systems that *do* things: fetch data, run queries, update tickets, generate code changes, and coordinate multi-step workflows—safely and reliably. That’s where AI agents come in.
#
# In this post, we’ll move from the basics of calling a language model to building tool-using systems that can plan, choose actions, execute tools, and react to results. You’ll learn practical architecture patterns you can implement today, including how to model agent state, define tool contracts, and enforce safety boundaries like allowlists and permissions.
#
# We’ll also cover the engineering side most teams underestimate: evaluation methods that catch regressions before users do, observability to debug step-by-step behavior, and reliability strategies to avoid common failure modes such as hallucinated tool calls or runaway loops. By the end, you’ll have a developer-focused blueprint for turning LLM capabilities into maintainable agent workflows.
#
# --- Planner Focused ---
#
# ## 1) Final title
# **From Prompt to Tool-Using Agent: A Practical Path to Building Something That Works**
#
# ## 2) Audience sentence
# This guide is for software engineers and technical writers who want to turn an LLM prompt into a reliable, tool-using agent with a concrete, step-by-step implementation.
#
# ## 3) 5-section outline
# 1. **Start with a plain LLM workflow**
#    - Define the task and expected output format
#    - Add guardrails (schema, constraints, and retries)
#
# 2. **Introduce tools as the next capability**
#    - Identify which external actions the model must take
#    - Map tool inputs/outputs to a stable interface
#
# 3. **Add an agent loop (plan → act → observe)**
#    - Use tool results as new context for the next step
#    - Handle failures, timeouts, and partial results
#
# 4. **Make it robust in production-like conditions**
#    - Add stopping criteria and budgets (steps, cost, latency)
#    - Validate outputs and implement safe fallback paths
#
# 5. **Evaluate and iterate**
#    - Create test cases that reflect real user intents
#    - Measure success (correctness, tool accuracy, failure rates)
#
# ## 4) 150–200 word intro
# Most “agent” tutorials begin with architecture diagrams and end with hand-wavy behavior. This article takes a different route: it starts where you already are—writing a prompt that produces correct output—and then upgrades that workflow until it becomes a tool-using agent you can actually run.
#
# You’ll begin with a plain LLM call and a strict output format, so you can see where failures come from. Next, you’ll introduce tools (functions, APIs, or scripts) and connect them to the model via clear input/output contracts. From there, you’ll implement a simple agent loop that decides when to call a tool, processes the tool’s response, and continues until it reaches a stopping condition. Finally, you’ll harden the system with practical controls like step limits, retries, validation, and fallback behavior, then evaluate it against realistic scenarios.
#
# The goal is not theoretical “intelligence.” It’s a dependable implementation path—from prompt to working agent.
#
# --- Planner Broad ---
#
# ## 1) Final title
# **Making Tool-Using LLM Agents Reliable: Structured Outputs, Typed Function Calls, and Policy Guardrails**
#
# ## 2) Audience sentence
# This guide is for developers building LLM “agents” that call tools (APIs, databases, workflows) and need predictable, testable behavior under real failure conditions.
#
# ## 3) 5-section outline
# 1. **Reliability starts at the output boundary**
#    - Use OpenAI Structured Outputs / `json_schema` (strict schema compliance)
#    - Why schema-valid arguments still need downstream validation
#
# 2. **Function calling with typed contracts**
#    - Define tool parameters with precise JSON Schema
#    - Handle tool-result types and error shapes deterministically
#
# 3. **Tool-call routing policies (reduce agent dynamism)**
#    - Use step-by-step orchestration where the workflow is known
#    - Apply termination criteria and explicit “next action” rules
#
# 4. **Runtime guardrails for tool loops**
#    - Add max tool calls / max iterations to prevent ReAct-style looping
#    - Intercept/wrap tool execution for retries, monitoring, and budgets
#
# 5. **Regression testing with golden traces**
#    - Build golden traces including tool calls + tool outputs
#    - Fail CI on drift; track changes that alter tool selection
#
# ## 4) 150–200 word intro
# Tool-using LLM agents fail in specific, concrete ways: arguments come back malformed, the agent picks the wrong tool, or it gets stuck in repetitive tool-call loops. Even if you “prompt harder,” these issues show up at runtime because the model is both generating text and controlling execution flow.
#
# This article focuses on reliability mechanisms that developers can implement directly. First, it uses OpenAI Structured Outputs to constrain tool-call arguments to a JSON Schema, which prevents common schema/type mismatches. Next, it shows how typed function calling becomes more dependable only when paired with orchestration and runtime policies: limiting tool-call counts, enforcing termination criteria, and wrapping tool execution for retries and observability.
#
# Finally, it turns reliability into an engineering practice with regression testing. By capturing golden traces—tool calls plus tool outputs—you can detect behavioral drift in CI, not after a production incident.

# %% [markdown]
# # Hand-off inspection
#
# Below you can inspect what was handed from one stage to the next.
#
# Use this to compare:
# - single LLM: no explicit hand-offs
# - focused planner: constrained research hand-off
# - broad planner: wider research hand-off

# %%
def _show_handoffs(final_state: dict, label: str):
    print(f"\n===== {label.upper()} HAND-OFFS =====\n")
    print("[1] propose -> reflect")
    print(final_state.get("options_json") or "")

    print("\n[2] reflect -> research")
    print(final_state.get("choice_json") or "")

    print("\n[3] research -> draft")
    print(final_state.get("sources_json") or "")

    print("\n[4] final draft")
    print(final_state.get("draft") or "")


_show_handoffs(final_focused, "planner focused")
_show_handoffs(final_broad, "planner broad")
# Out:
# ===== PLANNER FOCUSED HAND-OFFS =====
#
# [1] propose -> reflect
# {"options":[{"title":"LLM→Agent Evolution: Building the First Tool-Using Loop","audience":"Backend and full-stack developers who can code in Python/TypeScript and want a practical “from scratch” mental model","angle":"Start with a plain LLM call, then incrementally add planning, tool calling, state, retries, and safety—ending with a working tool-using agent.","outline":["Define the baseline: prompt→response and identify why it fails for real tasks","Add tool calling: JSON schema, function registry, and deterministic execution boundaries","Introduce an agent loop: plan→act→observe→continue until success/timeout","Handle real-world concerns: retries, backoff, idempotency, and partial failures","Package as a reusable pattern: interfaces, logging/tracing, and test harnesses with mocked tools"],"rationale":"Gives developers an actionable build path and a clear checklist of engineering concerns, turning “agent” terminology into tangible architecture."},{"title":"Architecting Agent Systems: State, Tools, Permissions, and Observability","audience":"Software architects and senior developers responsible for reliability, security, and maintainability","angle":"Treat agents as distributed systems: explicit state management, tool permissions, policy enforcement, and end-to-end observability.","outline":["Model the agent runtime: state store, session memory, and deterministic tool boundaries","Design tool access control: allowlists, scoped credentials, and least-privilege execution","Add policy + validation: prompt/tool output constraints, PII/unsafe-content gates","Observability by default: tracing spans, structured logs, and replayable traces for debugging","Evaluate with production-style metrics: success rate, tool error rate, latency, and cost per task"],"rationale":"Focuses on the engineering “gotchas” that determine whether an agent works in production—not just in demos."},{"title":"Testing & Evaluating Tool-Using Agents: From Unit Tests to Evals","audience":"Developers and ML engineers who want rigorous quality assurance for agent behavior","angle":"Show how to test and evaluate agents beyond “did it answer correctly?” using deterministic tool mocks, scenario suites, and regression evals.","outline":["Set up a testable architecture: dependency injection for tools and external services","Write unit tests for tool contracts: schemas, edge cases, and idempotent behavior","Create scenario-based integration tests with tool mocks and expected call sequences","Build an eval harness: task datasets, grading strategies (LLM-as-judge vs rule-based), and baselines","Prevent regressions: golden traces, performance budgets, and continuous evaluation in CI"],"rationale":"Provides a concrete QA/evaluation playbook so teams can iterate safely and measure improvements over time."}]}
#
# [2] reflect -> research
# {"choice_index":0,"rationale":"Option 0 is the clearest and most time-feasible choice while still being practically useful. Its progression from a simple LLM call to a working tool-using agent gives readers an intuitive mental model and a concrete implementation path, which is ideal for a limited-time talk or article. It is also reasonably original because it frames agents as an evolution of a familiar baseline rather than abstract theory. Compared with option 1, it is less architecture-heavy and more approachable; compared with option 2, it is broader and more immediately relevant to everyday developers who want to build something end-to-end, not just test it. The outline is well-scoped and naturally sequenced, making it realistic to cover without overloading the audience."}
#
# [3] research -> draft
#
#
# [4] final draft
# ## 1) Final title
# **From Prompt to Tool-Using Agent: A Practical Path to Building Something That Works**
#
# ## 2) Audience sentence
# This guide is for software engineers and technical writers who want to turn an LLM prompt into a reliable, tool-using agent with a concrete, step-by-step implementation.
#
# ## 3) 5-section outline
# 1. **Start with a plain LLM workflow**
#    - Define the task and expected output format
#    - Add guardrails (schema, constraints, and retries)
#
# 2. **Introduce tools as the next capability**
#    - Identify which external actions the model must take
#    - Map tool inputs/outputs to a stable interface
#
# 3. **Add an agent loop (plan → act → observe)**
#    - Use tool results as new context for the next step
#    - Handle failures, timeouts, and partial results
#
# 4. **Make it robust in production-like conditions**
#    - Add stopping criteria and budgets (steps, cost, latency)
#    - Validate outputs and implement safe fallback paths
#
# 5. **Evaluate and iterate**
#    - Create test cases that reflect real user intents
#    - Measure success (correctness, tool accuracy, failure rates)
#
# ## 4) 150–200 word intro
# Most “agent” tutorials begin with architecture diagrams and end with hand-wavy behavior. This article takes a different route: it starts where you already are—writing a prompt that produces correct output—and then upgrades that workflow until it becomes a tool-using agent you can actually run.
#
# You’ll begin with a plain LLM call and a strict output format, so you can see where failures come from. Next, you’ll introduce tools (functions, APIs, or scripts) and connect them to the model via clear input/output contracts. From there, you’ll implement a simple agent loop that decides when to call a tool, processes the tool’s response, and continues until it reaches a stopping condition. Finally, you’ll harden the system with practical controls like step limits, retries, validation, and fallback behavior, then evaluate it against realistic scenarios.
#
# The goal is not theoretical “intelligence.” It’s a dependable implementation path—from prompt to working agent.
#
# ===== PLANNER BROAD HAND-OFFS =====
#
# [1] propose -> reflect
# {"options":[{"title":"Agent Architecture in Practice: LLMs + Tools + Control Loops","audience":"Backend/frontend engineers, solution architects, and tech leads building agentic features","angle":"Go from “chat model” to a working tool-using agent by covering the control loop, tool interfaces, state management, and failure handling.","outline":["Define what changes between an LLM app and an agent (policy, tools, and iterative planning).","Design the tool contract (schemas, validation, idempotency, retries, and timeouts).","Implement the control loop (plan→act→observe→update) with stopping criteria and guardrails.","Add state and memory patterns (scratchpad vs. external state, session continuity, caching).","Evaluate and harden: logging, tracing, eval sets, and common failure modes (hallucinated tools, loops, partial execution)."],"rationale":"Developers need concrete architectural patterns and interfaces; this approach turns agent concepts into implementation-ready system design."},{"title":"From Prompting to Policies: Building Deterministic-ish Tool Use with Function Calling","audience":"ML engineers and developers working on reliability, safety, and predictable outputs","angle":"Focus on making tool-using behavior reliable using structured outputs, function/tool calling, constrained prompting, and policy-based decisioning.","outline":["Show a progression: free-form prompting → structured prompts → function calling/tool routing.","Build a tool-selection policy (rules, confidence thresholds, and allowed action sets).","Use schemas and structured outputs to prevent malformed arguments and reduce hallucinations.","Handle tool execution safely (permissions, sandboxing, and verifying preconditions).","Create a reliability harness: unit tests for tool invocation, golden traces, and regression evals."],"rationale":"Reliability is the biggest blocker for developers; emphasizing policies and structured tool use yields practical, testable agent behavior."},{"title":"Building an Agent Platform for Teams: Observability, Eval, and Cost-Control","audience":"Platform engineers, team leads, and developers scaling agent systems in production","angle":"Treat agents as a production system: instrumentation/observability, evaluation pipelines, and cost/latency management for real developer workflows.","outline":["Introduce a reference platform layer (agent registry, tool gateways, secrets/permissions, routing).","Add observability end-to-end (traces, spans, prompt/tool/response capture, redaction).","Set up agent evaluation (offline eval sets, scenario testing, metrics for success/failure/effort).","Control cost and latency (budgeting, model routing, caching, batching, and truncation strategies).","Operationalize with runbooks (incident handling, rollback strategies, and continuous improvement loops)."],"rationale":"Once agents go beyond demos, teams need platform practices; this approach helps developers ship and maintain agentic systems at scale."}]}
#
# [2] reflect -> research
# {"choice_index":1,"rationale":"Option 1 is the strongest overall balance of clarity, originality, developer relevance, and feasibility under time constraints. It has a crisp, teachable thesis: making tool-using agents more reliable through structured outputs, function calling, and policy-based decisioning. That angle is immediately useful to developers because reliability is a concrete pain point, and the outline maps well to practical implementation and testing.\n\nWhy it wins:\n- Clarity: the progression from prompting to policies is easy to follow and naturally structured.\n- Originality: it avoids a generic “build an agent” framing by centering on deterministic-ish behavior and reliability controls.\n- Developer relevance: function calling, schemas, tool routing, and regression evals are directly applicable to real systems.\n- Feasibility: it can be delivered effectively in a short session without needing a broad platform or deep system-design detour.\n\nCompared with the others: Option 0 is solid and practical, but broader and more architecture-heavy, which can make it feel less focused. Option 2 is valuable for production teams, but it leans more toward platform/ops concerns and may be less immediately actionable for a general developer audience within limited time. Option 1 is the most targeted and presentation-friendly choice."}
#
# [3] research -> draft
# {
#   "summary": [
#     {
#       "topic": "Reliability of OpenAI function calling / structured outputs",
#       "key_points": [
#         "OpenAI Structured Outputs (June 2024) guarantees function-call arguments match the provided JSON Schema exactly (key/type compliance).",
#         "This applies both to function calling and to structured response generation via response_format with json_schema.",
#         "Practical implication: the model is constrained to emit schema-valid JSON, greatly reducing malformed or missing fields vs older JSON-mode style prompting."
#       ],
#       "sources": [
#         "https://help.openai.com/en/articles/8555517-function-calling-in-the-openai-api",
#         "https://openai.com/index/introducing-structured-outputs-in-the-api/"
#       ]
#     },
#     {
#       "topic": "LangChain tool-calling reliability patterns",
#       "key_points": [
#         "Use LangChain’s tool-calling abstractions to enforce typed tool arguments and consistent tool dispatch.",
#         "Add agent middleware for operational guardrails: tool-call limits, interception/wrapping for retries/monitoring, and tighter control over tool execution loops."
#       ],
#       "sources": [
#         "https://docs.langchain.com/oss/python/langchain/frontend/tool-calling",
#         "https://reference.langchain.com/python/langchain/agents/middleware/types/AgentMiddleware/wrap_tool_call",
#         "https://reference.langchain.com/python/langchain/agents/middleware/tool_call_limit/ToolCallLimitMiddleware"
#       ]
#     },
#     {
#       "topic": "Common failure modes in tool-using agents (ReAct-like loops)",
#       "key_points": [
#         "Hallucinated tool names / malformed arguments can break parsing or dispatch, stalling or wasting steps.",
#         "Infinite or repetitive loops are common; you need a hard max-iteration cap and loop termination criteria.",
#         "These failure modes are architectural/runtime issues even when schemas are enforced—e.g., wrong tool choice or unhelpful observations."
#       ],
#       "sources": [
#         "https://memx.app/glossary/react-agent/",
#         "https://www.optiversetech.com/blog/agent-loops-react-tools-failure-modes/"
#       ]
#     },
#     {
#       "topic": "Deterministic-ish orchestration (avoid unnecessary agent dynamism)",
#       "key_points": [
#         "If your workflow is known/structured, deterministic routing (explicit step-by-step agents) reduces variability, cost, and latency.",
#         "This can complement tool-calling by reducing the surface area where the model must decide the next action."
#       ],
#       "sources": [
#         "https://opensource.microsoft.com/blog/2026/05/14/conductor-deterministic-orchestration-for-multi-agent-ai-workflows/",
#         "https://microsoft.github.io/autogen/stable/user-guide/core-user-guide/design-patterns/sequential-workflow.html"
#       ]
#     },
#     {
#       "topic": "Testing tool-using agents (golden traces / regression harnesses)",
#       "key_points": [
#         "Best practice: create regression tests using golden traces that include tool calls + tool outputs, then fail CI on drift.",
#         "Use frameworks that capture and compare OpenTelemetry-like traces or agent execution traces."
#       ],
#       "sources": [
#         "https://evalview.com/",
#         "https://www.kensa.sh/",
#         "https://pypi.org/project/agent-trace-eval/",
#         "https://github.com/agentevals-dev/agentevals"
#       ]
#     }
#   ],
#   "actionable_recommendations": [
#     "Prefer OpenAI Structured Outputs (json_schema / strict schema enforcement) for any tool-call arguments you require for safe downstream execution.",
#     "Treat tool reliability as a full system concern: schema-valid JSON is necessary but not sufficient (wrong tool choice and runtime/tool failures still happen).",
#     "Add runtime guardrails: max tool calls / max iterations, retries with capped budgets, and explicit termination criteria.",
#     "Build golden-trace regression tests that include tool-call sequences and outcomes; run them in CI to catch drift."
#   ],
#   "notes_on_your_provided_input": {
#     "status": "received",
#     "content_type": "search-result bundle",
#     "clarification_needed": "If you want, tell me your stack (OpenAI-only vs LangChain vs AutoGen) and desired language, and I’ll propose a concrete reliability checklist and test harness structure."
#   }
# }
#
# [4] final draft
# ## 1) Final title
# **Making Tool-Using LLM Agents Reliable: Structured Outputs, Typed Function Calls, and Policy Guardrails**
#
# ## 2) Audience sentence
# This guide is for developers building LLM “agents” that call tools (APIs, databases, workflows) and need predictable, testable behavior under real failure conditions.
#
# ## 3) 5-section outline
# 1. **Reliability starts at the output boundary**
#    - Use OpenAI Structured Outputs / `json_schema` (strict schema compliance)
#    - Why schema-valid arguments still need downstream validation
#
# 2. **Function calling with typed contracts**
#    - Define tool parameters with precise JSON Schema
#    - Handle tool-result types and error shapes deterministically
#
# 3. **Tool-call routing policies (reduce agent dynamism)**
#    - Use step-by-step orchestration where the workflow is known
#    - Apply termination criteria and explicit “next action” rules
#
# 4. **Runtime guardrails for tool loops**
#    - Add max tool calls / max iterations to prevent ReAct-style looping
#    - Intercept/wrap tool execution for retries, monitoring, and budgets
#
# 5. **Regression testing with golden traces**
#    - Build golden traces including tool calls + tool outputs
#    - Fail CI on drift; track changes that alter tool selection
#
# ## 4) 150–200 word intro
# Tool-using LLM agents fail in specific, concrete ways: arguments come back malformed, the agent picks the wrong tool, or it gets stuck in repetitive tool-call loops. Even if you “prompt harder,” these issues show up at runtime because the model is both generating text and controlling execution flow.
#
# This article focuses on reliability mechanisms that developers can implement directly. First, it uses OpenAI Structured Outputs to constrain tool-call arguments to a JSON Schema, which prevents common schema/type mismatches. Next, it shows how typed function calling becomes more dependable only when paired with orchestration and runtime policies: limiting tool-call counts, enforcing termination criteria, and wrapping tool execution for retries and observability.
#
# Finally, it turns reliability into an engineering practice with regression testing. By capturing golden traces—tool calls plus tool outputs—you can detect behavioral drift in CI, not after a production incident.

# %%
print("\n===== QUICK TAKEAWAY =====\n")
print("Single LLM: one call, no explicit hand-offs.")
print("Planner focused: clear hand-offs and constrained evidence gathering (1-2 searches).")
print("Planner broad: clear hand-offs but wider evidence gathering (3-5 searches).")
print("Use focused planning when you want tighter scope and lower latency.")
# Out:
# ===== QUICK TAKEAWAY =====
#
# Single LLM: one call, no explicit hand-offs.
# Planner focused: clear hand-offs and constrained evidence gathering (1-2 searches).
# Planner broad: clear hand-offs but wider evidence gathering (3-5 searches).
# Use focused planning when you want tighter scope and lower latency.

# %% [markdown]
# # Display the graph

# %%
from IPython.display import Image, display

display(Image(app.get_graph().draw_mermaid_png()))
